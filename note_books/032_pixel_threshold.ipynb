# %% [markdown]
# # Editing the Maize Root
#
# Numpy arithmetic

# %%
import imageio.v3 as iio
from image_processing import file_finder_service, image_display

maize_image_path = file_finder_service.find_training_image("maize-root-cluster.jpg")
maize_roots = iio.imread(uri=maize_image_path)
image_display.show(maize_roots, title="Maize Roots")

# %% [markdown]
# Then remove anything that isn't dark.

# %%
maize_roots[maize_roots < 128] = 0
image_display.show(maize_roots, title="Maize Roots - Thresholded")
