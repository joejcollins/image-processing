# %%
# Keep Low Intensity Regions

# %%
import imageio.v3 as iio
from image_processing import file_finder_service, image_display

sudoku_path = file_finder_service.find_training_image("sudoku.png")
sudoku_image = iio.imread(uri=sudoku_path, mode="L")
image_display.show(sudoku_image, title="Sudoku", cmap="gray")

# %%
from matplotlib import pyplot

sudoku_image[sudoku_image > 192] = 192
image_display.show(sudoku_image, title="Sudoku")

fig, ax = pyplot.subplots()
ax.imshow(sudoku_image, cmap="gray", vmax=225, vmin=0)
