# %% [markdown]
# # Slicing
#
# Extracting a local region of the image.

# %%
# %matplotlib widget
import imageio.v3 as iio
from aqua_marina import file_finder_service, image_display
from matplotlib import pyplot

board_path = file_finder_service.find_training_image("board.jpg")
board_image = iio.imread(uri=board_path)

fig, ax = pyplot.subplots()
ax.imshow(board_image)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fragment = board_image[80:140, 130:450]
fig, ax = pyplot.subplots()
ax.imshow(fragment)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bao
